# %%
from help_funcs import * 
# from eofs.xarray import Eof
import cartopy.crs as ccrs
import cartopy.feature as cfeature
import importlib
import xarray as xr
import seaborn as sns
import pandas as pd
import cmocean.cm as cm
import netCDF4 as nc
from pathlib import Path
from natsort import natsorted
import matplotlib.pyplot as plt
import gsw
import gc
from multiprocessing import Pool
import os 
import multiprocessing
from os.path import exists
sns.set_context("notebook")
import dask_labextension

# %%
t = np.arange(0, 1000)
row1 = np.cos(2 * np.pi * t/(100)) + 0.2 * np.cos((2 * np.pi * t/100) + (100 * np.pi / 2))
row2 = np.cos(2 * np.pi * t/(100))
x = np.array([row1,row2])

# %%
plt.plot(t, row1)
plt.plot(t, row2)

# %%
x_mean = np.mean(x, axis= 1)
x_nomean = x - x_mean
Y = # Y has dims = (location, time) 
u, s, vh  = linalg.svd(Y, full_matrices= False) #do svd

# %%
def do_EOF(x):
    ds_mean =   #remvove time average 
    ds_nomean = ds - ds_mean
    
    Y = np.array([a.flatten() for a in ds_nomean])
    Y = Y.T #reshape to space X time 

    not_wet_all = np.isnan(Y)
    not_wet = np.isnan(Y[:, 1]) #land mask 
    Y[not_wet_all] = 0.0 #remove nans 

    u, s, vh  = linalg.svd(Y, full_matrices= False) #do svd 
    
    return Y, (u, s, vh), ds_mean, not_wet
